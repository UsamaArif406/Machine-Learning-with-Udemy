# %%
from openai import OpenAI

# %%
api_key = "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"
client = OpenAI(api_key=api_key)

# %%
from openai import OpenAI

# Set your OpenAI API key
api_key = "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"

# Initialize the OpenAI client with the API key
client = OpenAI(api_key=api_key)

# Now you can make API requests
response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Who won the world series in 2020?"},
    {"role": "assistant", "content": "The Los Angeles Dodgers won the World Series in 2020."},
    {"role": "user", "content": "Where was it played?"}
  ]
)

# Continue processing the response or print the result as needed
print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 10
#       7 client = OpenAI(api_key=api_key)
#       9 # Now you can make API requests
# ---> 10 response = client.chat.completions.create(
#      11   model="gpt-3.5-turbo",
#      12   messages=[
#      13     {"role": "system", "content": "You are a helpful assistant."},
#      14     {"role": "user", "content": "Who won the world series in 2020?"},
#      15     {"role": "assistant", "content": "The Los Angeles Dodgers won the World Series in 2020."},
#      16     {"role": "user", "content": "Where was it played?"}
#      17   ]
#      18 )
#      20 # Continue processing the response or print the result as needed
#      21 print(response)
#
# File ~\anaconda3\Lib\site-packages\openai\_utils\_utils.py:271, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
# ...
